# %% [markdown]
# ## Problem Set 2: Construction FA
#
#
#
# _csc427, semester 222
# <br>
# university of miami
# <br>
# date: 2 feb 2022_

# %% [markdown]
# # Student name: Diep Vu
#
# ---

# %% [markdown]
# Please first complete the problem statement by filling in your implementation for the SimpleFiniteAutomata class. See the notes and class discussion if you do have a working implementation.
#
# Then answer the questions of Exercise A.

# %%
#
# an implementation might be released prior to the submission date and any
# extensions -bjr
#

class SimpleFiniteAutomata:
    
    def __init__(self,fa_description):
        self.fa = fa_description
        self.state = self.fa['start']
        
    def one_step(self,symbol):
        """
        takes a symbol (a string) and returns a state
        it is the state arrived at given the symbol at the current state
        """
        
        self.state = self.fa['transitions'][(self.state, symbol)]
        
        return self.state   # do not take this as a hint
        
    def compute(self,string):
        """
        takes a string and put the FA in the start state, then applies one_step
        to each symbol in the string.
        returns True if the FA ends in an accepting state; else returns False
        """
        
        # write code here 
        self.state = self.fa['start']
        
        for symbol in string:
            self.state = self.one_step(symbol)
     
        if self.state in self.fa['accept']:
            return True
        
        return False   # do not takes this as a hint
        

    
#end class SimpleFiniteAutomata


class SFAtest:
    
    def __init__(self, fa_description, fa_name):
        self.sfa = SimpleFiniteAutomata(fa_description)
        self.fa_name = fa_name
        
    def test(self, test_vect, verbose=False):
        tv_true, tv_false = test_vect
        correct = 0 

        print(f'*** testing {self.fa_name}')
        for string in tv_true:
            if self.sfa.compute(string):
                correct += 1
            else:
                print(f'should accept but does not: |{string}| ')
        print(f'\t{correct} correctly accepted out of {len(tv_true)} strings')
        passed = correct == len(tv_true)

        correct = 0 
        for string in tv_false:
            if not self.sfa.compute(string):
                correct += 1
            else:
                print(f'should reject but does not: |{string}| ')
        print(f'\t{correct} correctly rejected out of {len(tv_false)} strings')
 
        passed = passed and (correct == len(tv_false))
        if passed:
            print(f'*** PASSES\n')
        else:
            print(f'*** FAILS\n')
        return passed


#end class SFAtest

# %% [markdown]
# ### Exercise A
#
# Refering to the class texts, create FA for the languages in exercise 1.6, languages (a) through (h), and (m) and (n).
#
# I have given a few test cases for each. You will need that your FA work correctly, not just correctly on these test cases.

# %%
ex_1_6a = {
    'states':{'q0','q1','q2','q3'},
    'alphabet':{'0','1'},
    'transitions':{
        ('q0','1'):'q1', ('q0','0'):'q3',
        ('q1','1'):'q1', ('q1','0'):'q2',
        ('q2','0'):'q2', ('q2','1'):'q1', 
        ('q3','0'):'q3', ('q3','1'):'q3'
    },
    'start':'q0',
    'accept': {'q2'} 
}

ex_1_6a_test = (['10','100','110','1010','111000'],['','1','0','11','00','01','000101','11110001'])


ex_1_6b = {
    'states':{'q0','q1','q2','q3'},
    'alphabet':{'0','1'},
    'transitions':{
        ('q0','0'):'q0', ('q0','1'):'q1',
        ('q1','0'):'q1', ('q1','1'):'q2',
        ('q2','0'):'q2', ('q2','1'):'q3',
        ('q3','0'):'q3', ('q3','1'):'q3'
    },
    'start':'q0',
    'accept': {'q3'} 
}

ex_1_6b_test = (['111','1011','1101','1110','1111','10101'],
           ['','0','1','01','10','00','11','000','001','010','011','1010','1100','10000'])


ex_1_6c = {
    'states':{'q0','q1','q2','q3','q4'},
    'alphabet':{'0','1'},
    'transitions':{
        ('q0','0'):'q1', ('q0','1'):'q0',
        ('q1','0'):'q1', ('q1','1'):'q2',
        ('q2','0'):'q3', ('q2','1'):'q0',
        ('q3','0'):'q1', ('q3','1'):'q4',
        ('q4','0'):'q4', ('q4','1'):'q4'
    },
    'start':'q0',
    'accept': {'q4'} 
}

ex_1_6c_test = (['0101','00101','01011','110101','0010010100','1101101011'],
           ['','0','1','01','10','00','11','000','001','010','011','111','01101','01001','10100'])

ex_1_6d = {
    'states':{'q0','q1','q2','q3','q4'},
    'alphabet':{'0','1'},
    'transitions':{
        ('q0','0'):'q1', ('q0','1'):'q1',
        ('q1','0'):'q2', ('q1','1'):'q2',
        ('q2','0'):'q3', ('q2','1'):'q4',
        ('q3','0'):'q3', ('q3','1'):'q3',
        ('q4','0'):'q4', ('q4','1'):'q4'
    },
    'start':'q0',
    'accept': {'q3'} 
}

ex_1_6d_test = (['000','010','100','110','11011','00000','11011'],
           ['','0','1','01','10','00','11','001','111','01101','10100'])

ex_1_6e = {
    'states':{'q0','q1','q2','q3','q4'},
    'alphabet':{'0','1'},
    'transitions':{
        ('q0','0'):'q1', ('q0','1'):'q3',
        ('q1','0'):'q2', ('q1','1'):'q2',
        ('q2','0'):'q1', ('q2','1'):'q1',
        ('q3','0'):'q4', ('q3','1'):'q4',
        ('q4','0'):'q3', ('q4','1'):'q3'
    },
    'start':'q0',
    'accept': {'q1','q4'} 
}

ex_1_6e_test = (['0','11','10','000','001','010','011','1000','1010','1100','1111'],
           ['','1','01','00','111','100','101'])

ex_1_6f = {
    'states':{'q0','q1','q2','q3'},
    'alphabet':{'0','1'},
    'transitions':{
        ('q0','0'):'q0', ('q0','1'):'q1',
        ('q1','0'):'q0', ('q1','1'):'q2',
        ('q2','0'):'q3', ('q2','1'):'q2',
        ('q3','0'):'q3', ('q3','1'):'q3'
    },
    'start':'q0',
    'accept': {'q0','q1','q2'} 
}

ex_1_6f_test = (['','0','1','01','10','00','11','111','100','000','001','010','011','101'],
           ['110','0110','01100'])

ex_1_6g = {
    'states':{'q0','q1','q2','q3','q4','q5','q6'},
    'alphabet':{'0','1'},
    'transitions':{
        ('q0','0'):'q1', ('q0','1'):'q1',
        ('q1','0'):'q2', ('q1','1'):'q2',
        ('q2','0'):'q3', ('q2','1'):'q3',
        ('q3','0'):'q4', ('q3','1'):'q4',
        ('q4','0'):'q5', ('q4','1'):'q5',
        ('q5','0'):'q6', ('q5','1'):'q6',
        ('q6','0'):'q6', ('q6','1'):'q6'
    },
    'start':'q0',
    'accept': {'q0','q1','q2','q3','q4','q5'} 
}

ex_1_6g_test = (['','0','1','01','10','111','100','000','1010','0110','11100','00000'],
           ['000000','111111','010101','101010','11110000'])


ex_1_6h = {
    'states':{'q0','q1','q2','q3','q4'},
    'alphabet':{'0','1'},
    'transitions':{
        ('q0','0'):'q1', ('q0','1'):'q2',
        ('q1','0'):'q1', ('q1','1'):'q0',
        ('q2','0'):'q1', ('q2','1'):'q3',
        ('q3','0'):'q1', ('q3','1'):'q4',
        ('q4','0'):'q1', ('q4','1'):'q1'
    },
    'start':'q0',
    'accept': {'q0','q1','q2'} 
}

ex_1_6h_test = (['','0','1','01','10','00','100','000','001','010','11001111','11000111'],
           ['11','111'])

ex_1_6m = {
    'states':{'q1'},
    'alphabet':{'0','1'},
    'transitions':{
        ('q1','0'):'q1', ('q1','1'):'q1',
    },
    'start':'q1',
    'accept': {} 
}

ex_1_6m_test = ([],
           ['','0','1','11','111'])

ex_1_6n = {
    'states':{'q1','q2'},
    'alphabet':{'0','1'},
    'transitions':{
        ('q1','0'):'q2', ('q1','1'):'q2',
        ('q2','0'):'q2', ('q2','1'):'q2',
    },
    'start':'q1',
    'accept': {'q2'} 
}
ex_1_6n_test = (['0','1','11','111'],
           [''])



all_tests = [
    ('ex_1_6a',ex_1_6a,ex_1_6a_test),
    ('ex_1_6b',ex_1_6b,ex_1_6b_test),
    ('ex_1_6c',ex_1_6c,ex_1_6c_test),
    ('ex_1_6d',ex_1_6d,ex_1_6d_test),
    ('ex_1_6e',ex_1_6e,ex_1_6e_test),
    ('ex_1_6f',ex_1_6f,ex_1_6f_test),
    ('ex_1_6g',ex_1_6g,ex_1_6g_test),
    ('ex_1_6h',ex_1_6h,ex_1_6h_test),
    ('ex_1_6m',ex_1_6m,ex_1_6m_test),
    ('ex_1_6n',ex_1_6n,ex_1_6n_test)
]

def test_all(at):
    count = 0
    for t in at:
        test = SFAtest(t[1],t[0])
        if test.test(t[2]):
            count += 1

    if count == len(at):
        print('*** congratulations, passes all tests')
    else:
        print(f'*** passes {count} of {len(at)} test')


test_all(all_tests)
# Out:
# *** testing ex_1_6a
# 	5 correctly accepted out of 5 strings
# 	8 correctly rejected out of 8 strings
# *** PASSES
#
# *** testing ex_1_6b
# 	6 correctly accepted out of 6 strings
# 	14 correctly rejected out of 14 strings
# *** PASSES
#
# *** testing ex_1_6c
# 	6 correctly accepted out of 6 strings
# 	15 correctly rejected out of 15 strings
# *** PASSES
#
# *** testing ex_1_6d
# 	7 correctly accepted out of 7 strings
# 	11 correctly rejected out of 11 strings
# *** PASSES
#
# *** testing ex_1_6e
# 	11 correctly accepted out of 11 strings
# 	7 correctly rejected out of 7 strings
# *** PASSES
#
# *** testing ex_1_6f
# 	14 correctly accepted out of 14 strings
# 	3 correctly rejected out of 3 strings
# *** PASSES
#
# *** testing ex_1_6g
# 	12 correctly accepted out of 12 strings
# 	5 correctly rejected out of 5 strings
# *** PASSES
#
# *** testing ex_1_6h
# should accept but does not: |11001111|
# should accept but does not: |11000111|
# 	10 correctly accepted out of 12 strings
# ...
